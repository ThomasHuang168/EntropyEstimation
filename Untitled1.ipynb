# %%
import numpy as np
x = np.random.multivariate_normal( mean=[0,0,0],
                                  cov=[[1,0,-0.5],[0,1,-0.5],[-0.5,-0.5,1]],
                                 size = 300)
# x = np.random.multivariate_normal( mean=[0,0],
#                                   cov=[[1,0.8],[0.8,1]],
#                                  size = 300)
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.autograd as autograd
# x = np.append(x,np.array(x[:,0] x[:,1])[:,None], axis=1)
sns.scatterplot(x=x[:,0],y=x[:,1],color='r')
sns.scatterplot(x=x[:,0],y=x[:,2],color='g')
sns.scatterplot(x=x[:,1],y=x[:,2],color='b')
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x[:,0], x[:,1], x[:,2])
plt.show()
