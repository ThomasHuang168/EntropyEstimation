# %%
from pytorchtools import EarlyStopping
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.autograd as autograd

class Mine(nn.Module):
    def __init__(self, input_size=2, hidden_size=100):
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, 1)
        nn.init.normal_(self.fc1.weight,std=0.02)
        nn.init.constant_(self.fc1.bias, 0)
        nn.init.normal_(self.fc2.weight,std=0.02)
        nn.init.constant_(self.fc2.bias, 0)
        nn.init.normal_(self.fc3.weight,std=0.02)
        nn.init.constant_(self.fc3.bias, 0)
        
    def forward(self, input):
        output = F.elu(self.fc1(input))
        output = F.elu(self.fc2(output))
        output = self.fc3(output)
        return output

def mutual_information(joint, marginal, mine_net):
    t = mine_net(joint)
    et = torch.exp(mine_net(marginal))
    mi_lb = torch.mean(t) - torch.log(torch.mean(et))
    return mi_lb, t, et

def learn_mine(batch, mine_net, mine_net_optim,  ma_et, ma_rate=0.01):
    # batch is a tuple of (joint, marginal)
    joint , marginal = batch
    joint = torch.autograd.Variable(torch.FloatTensor(joint))
    marginal = torch.autograd.Variable(torch.FloatTensor(marginal))
    mi_lb , t, et = mutual_information(joint, marginal, mine_net)
    ma_et = (1-ma_rate)*ma_et + ma_rate*torch.mean(et)
    
    # unbiasing use moving average
    loss = -(torch.mean(t) - (1/ma_et.mean()).detach()*torch.mean(et))
    # use biased estimator
#     loss = - mi_lb
    
    mine_net_optim.zero_grad()
    autograd.backward(loss)
    mine_net_optim.step()
    return mi_lb, ma_et

def valid_mine(batch, mine_net):
    joint , marginal = batch
    joint = torch.autograd.Variable(torch.FloatTensor(joint))
    marginal = torch.autograd.Variable(torch.FloatTensor(marginal))
    mi_lb , t, et = mutual_information(joint, marginal, mine_net)
    return mi_lb
    

def create_dataset(data, batch_size=100):
    if data.shape[0] >= batch_size * 3:
        partSize = int(data.shape[0]/3)
        indices = list(range(data.shape[0]))
        np.random.shuffle(indices)
        valid_idx = indices[:partSize]
        test_idx = indices[partSize:partSize*2]
        train_idx = indices[partSize*2:]
        train_data = data[train_idx]
        valid_data = data[valid_idx]
        test_data = data[test_idx]
        return train_data, valid_data, test_data
    
def sample_batch(data, resp, cond, batch_size=100, sample_mode='joint'):
#     if sample_mode == 'joint':
#         index = np.random.choice(range(data.shape[0]), size=batch_size, replace=False)
#         batch = data[index]
#     else:
#         joint_index = np.random.choice(range(data.shape[0]), size=batch_size, replace=False)
#         marginal_index = np.random.choice(range(data.shape[0]), size=batch_size, replace=False)
#         batch = np.concatenate([data[joint_index][:,0].reshape(-1,1),
#                                          data[marginal_index][:,1].reshape(-1,1)],
#                                        axis=1)
    index = np.random.choice(range(data.shape[0]), size=batch_size, replace=False)
    batch_joint = data[index]
    marginal_index = np.random.choice(range(batch_joint.shape[0]), size=batch_size, replace=False)
    
#     print (batch_joint[:,0].reshape(-1,1).shape)
#     print (batch_joint[marginal_index][:,[1,2]].reshape(-1,2).shape)
    batch_mar = np.concatenate([batch_joint[:,resp].reshape(-1,1),
                                     batch_joint[marginal_index][:,cond].reshape(-1,2)],
                                   axis=1)
    return batch_joint, batch_mar

def train(data, mine_net,mine_net_optim, resp, cond, batch_size=100, iter_num=int(5e+4), log_freq=int(1e+3), avg_freq=int(1e+2), verbose=True):
    # data is x or y
    result = list()
    ma_et = 1.
    
    #Early Stopping
    train_losses = []
    valid_losses = []
    avg_train_losses = []
    avg_valid_losses = []
    
    earlyStop = EarlyStopping(patience=20, verbose=True)
    trainData, validData, testData = create_dataset(data, batch_size)
    for i in range(iter_num):
        #get train data
        batchTrain = sample_batch(trainData,batch_size=batch_size)
        mi_lb, ma_et = learn_mine(batchTrain, mine_net, mine_net_optim, ma_et)
        result.append(mi_lb.detach().cpu().numpy())
        train_losses.append(result[-1].item())
        if verbose and (i+1)%(log_freq)==0:
            print(result[-1])
        
        batchValid = sample_batch(validData,batch_size=batch_size)
        mi_lb_valid = valid_mine(batchValid, mine_net)
        valid_losses.append(mi_lb_valid.item())
        
        if (i+1)%(avg_freq)==0:
            train_loss = np.average(train_losses)
            valid_loss = np.average(valid_losses)
            avg_train_losses.append(train_loss)
            avg_valid_losses.append(valid_loss)

            iter_len = len(str(iter_num))
            print_msg = (f'[{i:>{iter_len}}/{iter_num:>{iter_len}}] ' +
                         f'train_loss: {train_loss:.5f} ' +
                         f'valid_loss: {valid_loss:.5f}')
            print (print_msg)

            train_losses = []
            valid_losses = []

            earlyStop(valid_loss, mine_net)
            if (earlyStop.early_stop):
                print("Early stopping")
                break
            
    mine_net.load_state_dict(torch.load('checkpoint.pt'))
    return mine_net, avg_train_losses, avg_valid_losses

def test(data, mine_net, mine_net_optim, batch_size=100):
    return data

def ma(a, window_size=100):
    return [np.mean(a[i:i+window_size]) for i in range(0,len(a)-window_size)]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
from scipy.stats import randint
import DiscreteCondEnt as DC

# %%
#MINE
mn0 = [0,0]
cov0 = [[1,0.5],[0.5,1]]

mn1 = [0,0,0]
cov1 = [[1,0,0.5],[0,1,0],[0.5,0,1]]
x = np.random.multivariate_normal( mean=mn1,cov=cov1,size = 1000)
mine_net = Mine(input_size = 3)
mine_net_optim = optim.Adam(mine_net.parameters(), lr=1e-3)
mine_net, train_loss, valid_loss = train(x,mine_net,mine_net_optim, verbose=False, avg_freq=1e+1)
result_ma = ma(valid_loss)
#MINE
# Out:
# [    9/50000] train_loss: 0.00006 valid_loss: 0.00008
# Validation loss decreased (inf --> 0.000079).  Saving model ...
# [   19/50000] train_loss: 0.00069 valid_loss: 0.00081
# Validation loss decreased (0.000079 --> 0.000813).  Saving model ...
# [   29/50000] train_loss: 0.00342 valid_loss: 0.00316
# Validation loss decreased (0.000813 --> 0.003163).  Saving model ...
# [   39/50000] train_loss: 0.01205 valid_loss: 0.01068
# Validation loss decreased (0.003163 --> 0.010683).  Saving model ...
# [   49/50000] train_loss: 0.02763 valid_loss: 0.03448
# Validation loss decreased (0.010683 --> 0.034476).  Saving model ...
# [   59/50000] train_loss: 0.06026 valid_loss: 0.04873
# Validation loss decreased (0.034476 --> 0.048725).  Saving model ...
# [   69/50000] train_loss: 0.07663 valid_loss: 0.06907
# Validation loss decreased (0.048725 --> 0.069066).  Saving model ...
# [   79/50000] train_loss: 0.09133 valid_loss: 0.08092
# Validation loss decreased (0.069066 --> 0.080917).  Saving model ...
# [   89/50000] train_loss: 0.05575 valid_loss: 0.09964
# Validation loss decreased (0.080917 --> 0.099645).  Saving model ...
# [   99/50000] train_loss: 0.13034 valid_loss: 0.08929
# EarlyStopping counter: 1 out of 20
# [  729/50000] train_loss: 0.15452 valid_loss: 0.11831
# EarlyStopping counter: 11 out of 20
# [  739/50000] train_loss: 0.13795 valid_loss: 0.13728
# EarlyStopping counter: 12 out of 20
# [  749/50000] train_loss: 0.18309 valid_loss: 0.20108
# Validation loss decreased (0.181501 --> 0.201080).  Saving model ...
# [  759/50000] train_loss: 0.13439 valid_loss: 0.14397
# EarlyStopping counter: 1 out of 20
# [  769/50000] train_loss: 0.13950 valid_loss: 0.13294
# EarlyStopping counter: 2 out of 20
# [  779/50000] train_loss: 0.09179 valid_loss: 0.15117
# EarlyStopping counter: 3 out of 20
# [  789/50000] train_loss: 0.14018 valid_loss: 0.09656
# EarlyStopping counter: 4 out of 20
# [  799/50000] train_loss: 0.14731 valid_loss: 0.11144
# EarlyStopping counter: 5 out of 20
# [  809/50000] train_loss: 0.11600 valid_loss: 0.13164
# EarlyStopping counter: 6 out of 20
# [  819/50000] train_loss: 0.12637 valid_loss: 0.11477
# EarlyStopping counter: 7 out of 20
# [  829/50000] train_loss: 0.13570 valid_loss: 0.13571
# EarlyStopping counter: 8 out of 20
# [  839/50000] train_loss: 0.15892 valid_loss: 0.13240
# EarlyStopping counter: 9 out of 20
# [  849/50000] train_loss: 0.12532 valid_loss: 0.14702
# EarlyStopping counter: 10 out of 20
# [  859/50000] train_loss: 0.11810 valid_loss: 0.11084
# EarlyStopping counter: 11 out of 20
# [  869/50000] train_loss: 0.11044 valid_loss: 0.13219
# EarlyStopping counter: 12 out of 20
# [  879/50000] train_loss: 0.12380 valid_loss: 0.10883
# EarlyStopping counter: 13 out of 20
# [  889/50000] train_loss: 0.13399 valid_loss: 0.13838
# EarlyStopping counter: 14 out of 20
# [  899/50000] train_loss: 0.16151 valid_loss: 0.16635
# EarlyStopping counter: 15 out of 20
# [  909/50000] train_loss: 0.10294 valid_loss: 0.14660
# EarlyStopping counter: 16 out of 20
# [  919/50000] train_loss: 0.12449 valid_loss: 0.12796
# EarlyStopping counter: 17 out of 20
# [  929/50000] train_loss: 0.09987 valid_loss: 0.12482
# EarlyStopping counter: 18 out of 20
# [  939/50000] train_loss: 0.10589 valid_loss: 0.12131
# EarlyStopping counter: 19 out of 20
# [  949/50000] train_loss: 0.12615 valid_loss: 0.12411
# EarlyStopping counter: 20 out of 20
# Early stopping
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-ae85bda30743> in <module>
#       9 mine_net_optim = optim.Adam(mine_net.parameters(), lr=1e-3)
#      10 mine_net, train_loss, valid_loss = train(x,mine_net,mine_net_optim, verbose=False, avg_freq=1e+1)
# ---> 11 result_ma = ma(valid_loss[-1])
#      12 #MINE
#
# <ipython-input-39-436224899b8c> in ma(a, window_size)
#     144
#     145 def ma(a, window_size=100):
# --> 146     return [np.mean(a[i:i+window_size]) for i in range(0,len(a)-window_size)]
#
# TypeError: object of type 'numpy.float64' has no len()

# %%
# visualize the loss as the network trained
fig = plt.figure(figsize=(10,8))
plt.plot(range(1,len(train_loss)+1),train_loss, label='Training Loss')
plt.plot(range(1,len(valid_loss)+1),valid_loss,label='Validation Loss')

# find position of lowest validation loss
minposs = valid_loss.index(min(valid_loss))+1 
plt.axvline(minposs, linestyle='--', color='r',label='Early Stopping Checkpoint')

plt.xlabel('epochs')
plt.ylabel('loss')
plt.ylim(0, 0.5) # consistent scale
plt.xlim(0, len(train_loss)+1) # consistent scale
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
